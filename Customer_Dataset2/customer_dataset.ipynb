# %% [markdown]
# This notebook is about K Means.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("customer_data.csv")
df.head()
# Out:
#    Annual_Income  Spending_Score
# 0      -5.772478       -4.818216
# 1       6.768246       -5.424570
# 2       5.796159       -6.239967
# 3       7.096022       -5.272612
# 4      -5.725561       -9.316889

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Annual_Income   1499 non-null   float64
#  1   Spending_Score  1499 non-null   float64
# dtypes: float64(2)
# memory usage: 23.6 KB

# %%
sns.scatterplot(data=df, x="Annual_Income", y="Spending_Score")
plt.show()

# %%
#Since we do not have a dependent feature here, we won't be using y
#we can train the whole model with df, or just train-test split it to test our model

from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df, test_size=0.3, random_state=34)

# %%
X_train
# Out:
#       Annual_Income  Spending_Score
# 1229      -5.245861      -11.279297
# 1353       7.574484       -5.803910
# 250       -4.628477      -10.143568
# 1166       4.890458       -5.809625
# 18        -4.996637      -10.493926
# ...             ...             ...
# 324        8.465084       -5.493865
# 1109      -5.956885       -3.344167
# 490       -9.451611       -3.178550
# 1146      -6.866996       -3.431314
# 1441      -5.187369      -10.036222
#
# [1049 rows x 2 columns]

# %%
X_test
# Out:
#       Annual_Income  Spending_Score
# 1036       6.313751       -4.632476
# 58        -8.855690       -4.506640
# 182        6.396831       -4.737292
# 1068      -3.995774       -7.509662
# 908       -7.113757       -4.325931
# ...             ...             ...
# 551       -8.477182       -4.807785
# 317       -4.852401       -9.648386
# 788       -3.845425      -10.334622
# 1320       6.795359       -6.109911
# 1422       7.781114       -5.507954
#
# [450 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.cluster import KMeans

#Elbow method to select K Value
wcss=[]
for k in range(1,11): #try k numbers from 1 to 11
    kmeans=KMeans(n_clusters=k,init="k-means++") 
    kmeans.fit(X_train_scaled)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [178.56018460590911,
#  61.245743776912306,
#  10.125809368547054,
#  8.453098968961255,
#  6.760460815359826,
#  5.279388559588931,
#  4.870876465923548,
#  4.433202278426157,
#  3.9438037545167837,
#  3.5137497957307247]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of Clustrers")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,init="k-means++")
kmeans.fit(X_train_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
y_pred=kmeans.predict(X_test_scaled)

# %%
sns.scatterplot(data=pd.DataFrame(X_test_scaled, columns=X_test.columns), x="Annual_Income", y="Spending_Score", hue=y_pred)
plt.show()

# %%
# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\sudet\appdata\local\programs\python\python312\lib\site-packages (from kneed) (2.3.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sudet\appdata\local\programs\python\python312\lib\site-packages (from kneed) (1.16.3)
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.6
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kneed import KneeLocator
#alternative

kl=KneeLocator(range(1,11), wcss, curve="convex", direction="decreasing")
kl.elbow
# Out:
# np.int64(3)

# %%
from sklearn.metrics import silhouette_score
#alternative

silhouette_coefficients=[]
for k in range(2,11): # it needs at least 2 cluster labels so we are not trying 1
    kmeans=KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(X_train_scaled)
    score=silhouette_score(X_train_scaled,kmeans.labels_) 
    silhouette_coefficients.append(score)

# %%
silhouette_coefficients
# Out:
# [0.6566319824493206,
#  0.7928369846659894,
#  0.6558604985981622,
#  0.5464808770192547,
#  0.39618455082574416,
#  0.3715593845771743,
#  0.4654804418493511,
#  0.3414431098407794,
#  0.35000680662013955]

# %%
plt.plot(range(2,11),silhouette_coefficients)
plt.xticks(range(2,11))
plt.xlabel("Number of Cluters")
plt.ylabel("Silhoutte Coeffecient")
plt.show()
